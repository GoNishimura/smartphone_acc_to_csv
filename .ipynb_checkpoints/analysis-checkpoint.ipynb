# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
walk_acc = pd.read_csv('data/walk/walk_acc.csv', names=['date', 'type', 'x', 'y', 'z'])

# %%
walk_acc = walk_acc.drop(['type'], axis=1)

# %%
walk_acc['dur'] = walk_acc['date'] - walk_acc['date'].min()
walk_acc = walk_acc.drop(['date'], axis=1)

# %%
walk_acc.head()
# Out:
#           x         y         z  dur
# 0  0.046328  0.046135  0.016743    0
# 1  0.046328  0.046135  0.016743   22
# 2  0.046328  0.046135  0.016743   41
# 3  0.046328  0.046135  0.016743   59
# 4  0.046328  0.046135  0.016743   71

# %%
pd.melt(walk_acc, ['dur']).head()
# Out:
#    dur variable     value
# 0    0        x  0.046328
# 1   22        x  0.046328
# 2   41        x  0.046328
# 3   59        x  0.046328
# 4   71        x  0.046328

# %%
def plot(name):
    split_name = name.split('_')
    cols = ['x', 'y', 'z']
    if split_name[1] == 'rot':
        cols = ['a', 'b', 'g']
        
    walk_acc = pd.read_csv('data/{}/{}.csv'.format(split_name[0], name), names=['date', 'type']+cols)
    walk_acc = walk_acc.drop(['type'], axis=1)
    walk_acc['dur'] = walk_acc['date'] - walk_acc['date'].min()
    walk_acc = walk_acc.drop(['date'], axis=1)
    ax = sns.lineplot(x='dur', y='value', hue='variable', data=pd.melt(walk_acc, ['dur']), alpha=0.5)
    ax.set_title('{} in {}'.format(split_name[0].title(), split_name[1].title()))
    ax.set_xlabel('duration in millisec')
    #ax.plot()
    plt.show()

# %%
data = 'walk'
for i in ['acc', 'gacc', 'rot']:
    plot('{}_{}'.format(data, i))

# %%
data = 'run'
for i in ['acc', 'gacc', 'rot']:
    plot('{}_{}'.format(data, i))

# %%
data = 'jump'
for i in ['acc', 'gacc', 'rot']:
    plot('{}_{}'.format(data, i))

# %%
data = 'pushup'
for i in ['acc', 'gacc', 'rot']:
    plot('{}_{}'.format(data, i))

# %%
pushup_gacc = pd.read_csv('data/pushup/pushup_gacc.csv', names=['date', 'type', 'x', 'y', 'z'])
pushup_gacc = pushup_gacc.drop(['type'], axis=1)
pushup_gacc['dur'] = pushup_gacc['date'] - pushup_gacc['date'].min()
pushup_gacc = pushup_gacc.drop(['date'], axis=1)

# %%
windowed = pushup_gacc.rolling(10).mean()

# %%
windowed.head(20)
# Out:
#            x         y         z    dur
# 0        NaN       NaN       NaN    NaN
# 1        NaN       NaN       NaN    NaN
# 2        NaN       NaN       NaN    NaN
# 3        NaN       NaN       NaN    NaN
# 4        NaN       NaN       NaN    NaN
# 5        NaN       NaN       NaN    NaN
# 6        NaN       NaN       NaN    NaN
# 7        NaN       NaN       NaN    NaN
# 8        NaN       NaN       NaN    NaN
# 9  -0.779013 -5.716455 -7.580791   78.9
# 10 -0.910575 -6.084953 -6.894433   96.9
# 11 -1.088165 -6.443978 -6.182876  114.4
# 12 -1.265755 -6.803004 -5.471320  131.6
# 13 -1.444257 -7.158738 -4.811448  147.7
# 14 -1.604684 -7.512152 -4.155870  164.5
# 15 -1.727761 -7.881308 -3.478730  180.6
# 16 -1.830801 -8.265667 -2.808114  197.2
# 17 -1.937029 -8.638339 -2.150217  213.8
# 18 -2.121128 -8.986756 -1.477641  230.8
# 19 -2.341439 -9.327570 -0.724395  247.5

# %%
ax = sns.lineplot(x='dur', y='value', hue='variable', data=pd.melt(pushup_gacc, ['dur']), alpha=0.5)
ax.set_title('{} in {}'.format('pushup', 'gcc'))
ax.set_xlabel('duration in millisec')
#ax.plot()
plt.show()

# %%
ax = sns.lineplot(x='dur', y='value', hue='variable', data=pd.melt(windowed, ['dur']), alpha=0.5)
ax.set_title('{} in {}'.format('pushup', 'gcc'))
ax.set_xlabel('duration in millisec')
#ax.plot()
plt.show()
